# %% [markdown]
# <a href="https://colab.research.google.com/github/c-susan/sqlite_database_operations/blob/main/cleaning_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Loading Packages

# %%
import pandas as pd
import re

# %% [markdown]
# # Loading Datasets
#
# Loaded 2 datasets on pricing transparency of two hospital, St. Charles Hospital and Stony Brook University Hospital.

# %% [markdown]
# > **Dataset from St. Charles Hospital**

# %%
df_stcharles = pd.read_csv('https://raw.githubusercontent.com/c-susan/sqlite_database_operations/main/datasets/st.-charles-hospital_standardcharges.csv')

# %%
# Checking the size / number of rows and columns in the data
df_stcharles.shape
# Out:
# (65050, 10)

# %%
# Previewing the dataset
df_stcharles.sample(5)
# Out:
#        Billing/Charge Code                           Charge Description   \
# 38204           2780171301          ORMS&D RADIUS SCREW STANDARD 4.75X55
# 49986           2780177600              ORMS&D VNGD SSK 360 FEMUR L 62.5
# 60317           6360000001      XRX METOPROLOL TARTRATE 5 MG/5ML IV SOLN
# 21136           2780000057          ORMS&D COROENT SI TA MARKERS 7X17X14
# 58805           6360000001  XRX KETOROLAC TROMETHAMINE 60 MG/2ML IM SOLN
#
#        Rev Code CPT/HCPC     Price           NDC  Package Size Package Unit  \
# 38204       278    C1713   3421.25           NaN           NaN          NaN
# 49986       278    C1776  27830.00           NaN           NaN          NaN
# 60317       636    J3490      7.00  47781-587-20           5.0           mL
# 21136       278    C1889  10925.00           NaN           NaN          NaN
# 58805       636    J1885     39.00  25021-701-02           2.0           mL
#
#       Package Description Charge Quantity
# 38204                 NaN             NaN
# 49986                 NaN             NaN
# 60317                Vial            5 mL
# 21136                 NaN             NaN
# 58805                Vial            2 mL

# %% [markdown]
# > **Dataset from Stony Brook University Hospital**

# %%
df_stonybrook = pd.read_csv('https://raw.githubusercontent.com/c-susan/sqlite_database_operations/main/datasets/StonyBrookUniversityHospital_standardcharges.csv')

# %%
# Checking the size / number of rows and columns in the data
df_stonybrook.shape
# Out:
# (7710, 57)

# %%
# Previewing the dataset
df_stonybrook.sample(5)
# Out:
#           Code                                     Description        Type  \
# 4481     85520                                   HEPARIN ASSAY  Outpatient
# 6465      404X  Thyroid, Parathyroid & Thyroglossal Procedures   Inpatient
# 7530  30791057                         R&B OVERFLOW IP 8  PT-T         NaN
# 7709  30000004                                    SEMI-PRIVATE         NaN
# 5457     C1750    CATHETER, HEMODIALYSIS/PERITONEAL, LONG-TERM  Outpatient
#
#      Package/Line_Level  Gross charge  Discounted cash price  \
# 4481               Line        854.86                 854.86
# 6465               Line      67479.28               67479.28
# 7530                NaN       8165.00                8165.00
# 7709                NaN       8165.00                8165.00
# 5457               Line        683.40                 683.40
#
#       De-identified min contracted rate  De-identified max contracted rate  \
# 4481                              11.13                             856.00
# 6465                            7479.87                            7479.87
# 7530                                NaN                                NaN
# 7709                                NaN                                NaN
# 5457                             212.77                             360.67
#
#       Derived contracted rate  1199-Commercial other  ...  \
# 4481                   308.52                    NaN  ...
# 6465                  7479.87                    NaN  ...
# 7530                      NaN                    NaN  ...
# 7709                      NaN                    NaN  ...
# 5457                   286.72                    NaN  ...
#
#       Optum-Commercial other  Oxford-Commercial other  \
# 4481                     NaN                   582.08
# 6465                     NaN                      NaN
# 7530                     NaN                      NaN
# 7709                     NaN                      NaN
# 5457                     NaN                      NaN
#
#       Oxford-Commercial HMO/POS  Tricare-Commercial other  \
# 4481                        NaN                       NaN
# 6465                        NaN                       NaN
# 7530                        NaN                       NaN
# 7709                        NaN                       NaN
# 5457                        NaN                       NaN
#
#       United Healthcare-Commercial other  \
# 4481                               642.0
# 6465                                 NaN
# 7530                                 NaN
# 7709                                 NaN
# 5457                                 NaN
#
#       United Healthcare-Medicare Advantage HMO  \
# 4481                                       NaN
# 6465                                       NaN
# 7530                                       NaN
# 7709                                       NaN
# 5457                                       NaN
#
#       United Healthcare-Commercial HMO/POS  United Healthcare-Medicaid HMO  \
# 4481                                   NaN                           13.09
# 6465                                   NaN                         7479.87
# 7530                                   NaN                             NaN
# 7709                                   NaN                             NaN
# 5457                                   NaN                             NaN
#
#       United Healthcare-Commercial PPO/Open Access  \
# 4481                                           NaN
# 6465                                           NaN
# 7530                                           NaN
# 7709                                           NaN
# 5457                                           NaN
#
#       Veteran Family-Commercial other
# 4481                              NaN
# 6465                              NaN
# 7530                              NaN
# 7709                              NaN
# 5457                              NaN
#
# [5 rows x 57 columns]

# %% [markdown]
# # Cleaning Column Names

# %% [markdown]
# > **St. Charles Hospital**

# %%
# Remove leading and trailing white space from a column
df_stcharles.columns = df_stcharles.columns.str.strip()

# Function to remove white space and special characters from a value
def clean_column_names(df):
    # Define a helper function to clean column names
    def clean_name(name):
        cleaned_name = re.sub(r'[^a-zA-Z0-9]', '_', name)
        return cleaned_name.lower()

    # Rename columns using the helper function
    # This is using a list comprehend - e.g., we have a list to the right of the equals sign,
    # and inside the list, we are applying our function, for every col (or X) that exists in df.columns
    df_stcharles.columns = [clean_name(col) for col in df_stcharles.columns]
    return df_stcharles

# Apply the clean_value function to all columns
df_stcharles = clean_column_names(df_stcharles)

# %%
df_stcharles.sample(5)
# Out:
#        billing_charge_code                                 charge_description  \
# 63591           6360000001   XRX SODIUM CHLORIDE 0.9 % IV SOLN (PED DISCRETE)
# 55524           6360000001  XRX DEXAMETHASONE SOD PHOSPHATE PF 10 MG/ML IJ...
# 57865           6360000001  XRX HEPARIN (PORCINE) IN NACL 1000-0.9 UT/500M...
# 25884           2780000061                      ORMS&D FORTIFY 35-54MM HEIGHT
# 29995           2780000059              ORMS&D KNEE FEM TRULIANT CR POR 3.5LT
#
#        rev_code cpt_hcpc    price           ndc  package_size package_unit  \
# 63591       636    J7050     41.0  0338-0553-18         100.0           mL
# 55524       636    J1100     48.0  63323-506-01           1.0           mL
# 57865       636    J1644     35.0  0338-0424-18         500.0           mL
# 25884       278    C1889  27312.5           NaN           NaN          NaN
# 29995       278    C1889  12765.0           NaN           NaN          NaN
#
#       package_description charge_quantity
# 63591           Flex Cont          100 mL
# 55524                Vial            1 mL
# 57865           Flex Cont          500 mL
# 25884                 NaN             NaN
# 29995                 NaN             NaN

# %% [markdown]
# > **Stony Brook University Hospital**

# %%
# Remove leading and trailing white space from a column
df_stonybrook.columns = df_stonybrook.columns.str.strip()

# Function to remove white space and special characters from a value
def clean_column_names(df):
    # Define a helper function to clean column names
    def clean_name(name):
        cleaned_name = re.sub(r'[^a-zA-Z0-9]', '_', name)
        return cleaned_name.lower()

    # Rename columns using the helper function
    # This is using a list comprehend - e.g., we have a list to the right of the equals sign,
    # and inside the list, we are applying our function, for every col (or X) that exists in df.columns
    df_stonybrook.columns = [clean_name(col) for col in df_stonybrook.columns]
    return df_stonybrook

# Apply the clean_value function to all columns
df_stonybrook = clean_column_names(df_stonybrook)

# %%
df_stonybrook.sample(5)
# Out:
#        code                                        description        type  \
# 5097  93662  ULTRASOUND EVALUATION OF HEART BLOOD VESSEL WI...  Outpatient
# 4344  83835                                METANEPHRINES LEVEL  Outpatient
# 812   26115  REMOVAL (LESS THAN 1.5 CENTIMETERS) TISSUE BEN...  Outpatient
# 2640  54416  REMOVAL AND REPLACEMENT OF NONINFLATABLE PENIL...  Outpatient
# 4135  81120  GENE ANALYSIS (ISOCITRATE DEHYDROGENASE 1 [NAD...  Outpatient
#
#      package_line_level  gross_charge  discounted_cash_price  \
# 5097               Line      11853.90               11853.90
# 4344               Line         36.73                  36.73
# 812             Package       3496.29                3496.29
# 2640            Package      31355.75               31355.75
# 4135               Line        184.00                 184.00
#
#       de_identified_min_contracted_rate  de_identified_max_contracted_rate  \
# 5097                             225.33                             4509.0
# 4344                               4.00                               30.0
# 812                             1479.92                             5902.5
# 2640                                NaN                                NaN
# 4135                                NaN                                NaN
#
#       derived_contracted_rate  1199_commercial_other  ...  \
# 5097                  2792.48                    NaN  ...
# 4344                    19.02                   25.2  ...
# 812                   4732.28                    NaN  ...
# 2640                      NaN                    NaN  ...
# 4135                      NaN                    NaN  ...
#
#       optum_commercial_other  oxford_commercial_other  \
# 5097                     NaN                      NaN
# 4344                   16.94                      NaN
# 812                      NaN                      NaN
# 2640                     NaN                      NaN
# 4135                     NaN                      NaN
#
#       oxford_commercial_hmo_pos  tricare_commercial_other  \
# 5097                        NaN                       NaN
# 4344                        NaN                       NaN
# 812                         NaN                       NaN
# 2640                        NaN                       NaN
# 4135                        NaN                       NaN
#
#       united_healthcare_commercial_other  \
# 5097                                 NaN
# 4344                                30.0
# 812                               5127.0
# 2640                                 NaN
# 4135                                 NaN
#
#       united_healthcare_medicare_advantage_hmo  \
# 5097                                       NaN
# 4344                                       NaN
# 812                                        NaN
# 2640                                       NaN
# 4135                                       NaN
#
#       united_healthcare_commercial_hmo_pos  united_healthcare_medicaid_hmo  \
# 5097                                   NaN                             NaN
# 4344                                   NaN                           16.94
# 812                                    NaN                         1479.92
# 2640                                   NaN                             NaN
# 4135                                   NaN                             NaN
#
#       united_healthcare_commercial_ppo_open_access  \
# 5097                                           NaN
# 4344                                           NaN
# 812                                            NaN
# 2640                                           NaN
# 4135                                           NaN
#
#       veteran_family_commercial_other
# 5097                              NaN
# 4344                              NaN
# 812                               NaN
# 2640                              NaN
# 4135                              NaN
#
# [5 rows x 57 columns]

# %% [markdown]
# # Checking for Null Values in Dataset

# %%
df_stcharles.isnull().sum()
# Out:
# billing_charge_code        0
# charge_description         0
# rev_code                   0
# cpt_hcpc               14525
# price                     92
# ndc                    52338
# package_size           52338
# package_unit           52338
# package_description    52401
# charge_quantity        52338
# dtype: int64

# %%
df_stonybrook.isnull().sum()
# Out:
# code                                               0
# description                                        0
# type                                             783
# package_line_level                               783
# gross_charge                                       0
# discounted_cash_price                              0
# de_identified_min_contracted_rate               1456
# de_identified_max_contracted_rate               1456
# derived_contracted_rate                         1456
# 1199_commercial_other                           6696
# aetna_medicare_advantage_hmo                    6604
# aetna_commercial_hmo_pos                        5883
# aetna_commercial_ppo_open_access                6098
# aetna_commercial_other                          7582
# empire_health_commercial_other                  4650
# empire_health_commercial_ppo_open_access        5308
# bluecross_blueshield_commercial_other           6456
# beacon_health_commercial_other                  7707
# carelon_health_commercial_other                 7707
# cigna_commercial_ppo_open_access                5744
# cigna_commercial_other                          7667
# cigna_commercial_hmo_pos                        7704
# eh_facet_commercial_other                       7710
# emblemhealth_commercial_ppo_open_access         6964
# emblemhealth_commercial_other                   5640
# emblemhealth_commercial_hmo_pos                 6324
# emblemhealth_medicaid_hmo                       7710
# emblemhealth_medicare_advantage_hmo             7710
# empire_health_commercial_hmo_pos                6031
# empire_health_medicare_advantage_hmo            6636
# empire_health_medicaid_hmo                      7708
# evernorth_commercial_other                      7702
# fidelis_commercial_other                        6790
# fidelis_medicare_advantage_hmo                  7442
# fidelis_medicaid_hmo                            5353
# ghi_commercial_other                            7710
# healthfirst_commercial_other                    5634
# healthfirst_medicare_advantage_hmo              7608
# healthfirst_medicaid_hmo                        7710
# healthplus_hp_medicaid_hmo                      6920
# healthplus_hp_commercial_other                  7413
# healthplus_hp_medicare_advantage_hmo            7005
# humana_commercial_other                         7677
# humana_commercial_hmo_pos                       7463
# humana_commercial_ppo_open_access               7236
# meritain_health_commercial_other                7260
# molina_commercial_other                         6963
# optum_commercial_other                          6767
# oxford_commercial_other                         5933
# oxford_commercial_hmo_pos                       7710
# tricare_commercial_other                        7276
# united_healthcare_commercial_other              5353
# united_healthcare_medicare_advantage_hmo        7086
# united_healthcare_commercial_hmo_pos            7577
# united_healthcare_medicaid_hmo                  5645
# united_healthcare_commercial_ppo_open_access    7353
# veteran_family_commercial_other                 7664
# dtype: int64

# %% [markdown]
# # Data Types and Conversions

# %%
# Changed the data type of the "billing_charge_code" and "rev_code" columns from integer to a string.
df_stcharles[['billing_charge_code', 'rev_code']] = df_stcharles[['billing_charge_code', 'rev_code']].astype(str)
df_stcharles.dtypes
# Out:
# billing_charge_code     object
# charge_description      object
# rev_code                object
# cpt_hcpc                object
# price                  float64
# ndc                     object
# package_size           float64
# package_unit            object
# package_description     object
# charge_quantity         object
# dtype: object

# %%
df_stonybrook.dtypes
# Out:
# code                                             object
# description                                      object
# type                                             object
# package_line_level                               object
# gross_charge                                    float64
# discounted_cash_price                           float64
# de_identified_min_contracted_rate               float64
# de_identified_max_contracted_rate               float64
# derived_contracted_rate                         float64
# 1199_commercial_other                           float64
# aetna_medicare_advantage_hmo                    float64
# aetna_commercial_hmo_pos                        float64
# aetna_commercial_ppo_open_access                float64
# aetna_commercial_other                          float64
# empire_health_commercial_other                  float64
# empire_health_commercial_ppo_open_access        float64
# bluecross_blueshield_commercial_other           float64
# beacon_health_commercial_other                  float64
# carelon_health_commercial_other                 float64
# cigna_commercial_ppo_open_access                float64
# cigna_commercial_other                          float64
# cigna_commercial_hmo_pos                        float64
# eh_facet_commercial_other                       float64
# emblemhealth_commercial_ppo_open_access         float64
# emblemhealth_commercial_other                   float64
# emblemhealth_commercial_hmo_pos                 float64
# emblemhealth_medicaid_hmo                       float64
# emblemhealth_medicare_advantage_hmo             float64
# empire_health_commercial_hmo_pos                float64
# empire_health_medicare_advantage_hmo            float64
# empire_health_medicaid_hmo                      float64
# evernorth_commercial_other                      float64
# fidelis_commercial_other                        float64
# fidelis_medicare_advantage_hmo                  float64
# fidelis_medicaid_hmo                            float64
# ghi_commercial_other                            float64
# healthfirst_commercial_other                    float64
# healthfirst_medicare_advantage_hmo              float64
# healthfirst_medicaid_hmo                        float64
# healthplus_hp_medicaid_hmo                      float64
# healthplus_hp_commercial_other                  float64
# healthplus_hp_medicare_advantage_hmo            float64
# humana_commercial_other                         float64
# humana_commercial_hmo_pos                       float64
# humana_commercial_ppo_open_access               float64
# meritain_health_commercial_other                float64
# molina_commercial_other                         float64
# optum_commercial_other                          float64
# oxford_commercial_other                         float64
# oxford_commercial_hmo_pos                       float64
# tricare_commercial_other                        float64
# united_healthcare_commercial_other              float64
# united_healthcare_medicare_advantage_hmo        float64
# united_healthcare_commercial_hmo_pos            float64
# united_healthcare_medicaid_hmo                  float64
# united_healthcare_commercial_ppo_open_access    float64
# veteran_family_commercial_other                 float64
# dtype: object

# %% [markdown]
# # Removing Duplicates

# %%
df_stcharles.drop_duplicates()
df_stcharles.shape
# Out:
# (65050, 10)

# %%
df_stonybrook.drop_duplicates()
df_stonybrook.shape
# Out:
# (7710, 57)

# %% [markdown]
# **____________________________________________________________________________________________________________**

# %% [markdown]
# Moved cleaned datasets onto a new file.

# %%
df_stcharles.to_csv('cleaned_stcharles_standard_charges.csv', index=False)

# %%
df_stonybrook.to_csv('cleaned_stonybrook_standard_charges.csv', index=False)
